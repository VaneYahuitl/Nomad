# %% [markdown]
# <a href="https://colab.research.google.com/github/VaneYahuitl/Nomad/blob/main/Actinobacter_indiferentsoils.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import plotly.express as px
import pandas as pd
import numpy as np
import matplotlib

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4481102a-026d-4207-a068-d95bccafcd2d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4481102a-026d-4207-a068-d95bccafcd2d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Acidobacter_compare.csv to Acidobacter_compare.csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['Acidobacter_compare.csv']))
df
# Out:
#                  Phyl        D1        D3        D7       D14       D28  \
# 0  Chinampa Unamended  0.246647  0.308785  0.250735  0.243322  0.190302
# 1    Chinampa Amended  0.157214  0.141563  0.154466  0.154411  0.140719
# 2     Texcoco Amended  0.192130  0.174652  0.192576  0.210701  0.195204
# 3   Texcoco Unamended  0.282315  0.286529  0.219741  0.227099  0.343648
# 4  Batán-CA-Unamended  0.240000  0.210000  0.240000  0.210000  0.180000
# 5  Batán-CP-Unamended  0.110000  0.100000  0.160000  0.140000  0.100000
# 6    Batán-CA-Amended  0.180000  0.180000  0.150000  0.180000  0.180000
# 7    Batán-CP-Amended  0.040000  0.080000  0.050000  0.130000  0.100000
#
#         D56
# 0  0.338794
# 1  0.235196
# 2  0.192927
# 3  0.291688
# 4  0.250000
# 5  0.150000
# 6  0.180000
# 7  0.080000

# %%
df_m = pd.melt(df, id_vars=['Phyl'], value_vars=None)
df_m
# Out:
#                   Phyl variable     value
# 0   Chinampa Unamended       D1  0.246647
# 1     Chinampa Amended       D1  0.157214
# 2      Texcoco Amended       D1  0.192130
# 3    Texcoco Unamended       D1  0.282315
# 4   Batán-CA-Unamended       D1  0.240000
# 5   Batán-CP-Unamended       D1  0.110000
# 6     Batán-CA-Amended       D1  0.180000
# 7     Batán-CP-Amended       D1  0.040000
# 8   Chinampa Unamended       D3  0.308785
# 9     Chinampa Amended       D3  0.141563
# 10     Texcoco Amended       D3  0.174652
# 11   Texcoco Unamended       D3  0.286529
# 12  Batán-CA-Unamended       D3  0.210000
# 13  Batán-CP-Unamended       D3  0.100000
# 14    Batán-CA-Amended       D3  0.180000
# 15    Batán-CP-Amended       D3  0.080000
# 16  Chinampa Unamended       D7  0.250735
# 17    Chinampa Amended       D7  0.154466
# 18     Texcoco Amended       D7  0.192576
# 19   Texcoco Unamended       D7  0.219741
# 20  Batán-CA-Unamended       D7  0.240000
# ...

# %%
px.histogram(df_m, x= "variable", y="value", color="Phyl")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter(df_m, x= "variable", y="value", color="Phyl")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(df_m, x= "variable", y= "value", color="Phyl", hover_name="Phyl", marginal="rug", facet_col="Phyl")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.sunburst(df_m, values="value", path=["Phyl","value"], color="Phyl", hover_name="Phyl", height=500)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
